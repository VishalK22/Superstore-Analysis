# %%
#Importing the libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sklearn
# Out:
# C:\Users\s.DESKTOP-CSGKT6S.000\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
cr = pd.read_csv(r"F:\Data Science\Crisil Assignment\Sample - Superstore.csv",encoding='latin1')

# %%
cr.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
cr.shape
# Out:
# (9994, 21)

# %%
# Checking the column names
cr.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# Checking the data types
cr.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
# Checking null values
cr.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
cr.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
sns.pairplot(cr,hue='Ship Mode')

# %%
cr.duplicated().sum()
# Out:
# 1

# %%
cr.nunique()
# Out:
# Order ID         5009
# Order Date       1237
# Ship Date        1334
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# City              531
# State              49
# Postal Code       631
# Region              4
# Product ID       1862
# Category            3
# Sub-Category       17
# Product Name     1850
# Sales            5825
# Quantity           14
# Discount           12
# Profit           7287
# year                5
# dtype: int64

# %%
corelation=cr.corr()

# %%
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)

# %%
sns.pairplot(cr)

# %%
# Dropping the Row ID column
cr=cr.drop('Row ID',axis=1)
cr.head()
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
cr['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
# Dropping the Country column
cr=cr.drop('Country',axis=1)
cr.head()
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment             City       State  Postal Code  \
# 0      Claire Gute   Consumer        Henderson    Kentucky        42420
# 1      Claire Gute   Consumer        Henderson    Kentucky        42420
# 2  Darrin Van Huff  Corporate      Los Angeles  California        90036
# 3   Sean O'Donnell   Consumer  Fort Lauderdale     Florida        33311
# 4   Sean O'Donnell   Consumer  Fort Lauderdale     Florida        33311
#
#   Region       Product ID         Category Sub-Category  \
# ...

# %%
cr.shape
# Out:
# (9994, 19)

# %%
# Analyzing the Profit column
sns.barplot(cr['Profit'],palette='twilight')

# %%
# Analyzing the Discount column
sns.barplot(cr['Discount'],palette='twilight')

# %%
# Seprating the year from Ship Date column
cr['year'] = pd.DatetimeIndex(cr['Ship Date']).year
cr.head()
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment             City       State  Postal Code  \
# 0      Claire Gute   Consumer        Henderson    Kentucky        42420
# 1      Claire Gute   Consumer        Henderson    Kentucky        42420
# 2  Darrin Van Huff  Corporate      Los Angeles  California        90036
# 3   Sean O'Donnell   Consumer  Fort Lauderdale     Florida        33311
# 4   Sean O'Donnell   Consumer  Fort Lauderdale     Florida        33311
#
#   Region       Product ID         Category Sub-Category  \
# ...

# %%
# Unique value count in every year
cr["year"].value_counts()
# Out:
# 2017    3303
# 2016    2578
# 2015    2131
# 2014    1940
# 2018      42
# Name: year, dtype: int64

# %%
# Analyzing the Profit and Discount column in every year 
cr.groupby('year')['Profit','Discount'].agg(['sum']).plot.bar()
plt.title('Total Profit and Discount per Sub-Category')
plt.show()
# Out:
# C:\Users\s.DESKTOP-CSGKT6S.000\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
cr.groupby('year')['Profit'].agg(['sum']).plot.bar()
plt.title('Total Profit per Year')
plt.show()

# %%
cr.groupby('year')['Discount'].agg(['sum']).plot.bar()
plt.title('Total Discount per Year')
plt.show()

# %%
cr.groupby('year')['Profit','Discount'].agg(['sum']).plot.barh(width=1, figsize=(18,5))
plt.title('Total Profit and Discount per Sub-Category')
plt.show()
# Out:
# C:\Users\s.DESKTOP-CSGKT6S.000\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
# Analyzing the category column
cr['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
cr['Sub-Category'].nunique()
# Out:
# 17

# %%
cr['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=(16,8))
plt.bar('Sub-Category','Category',data=cr,color='y')
plt.show()

# %%
plt.figure(figsize=(12,10))
cr['Sub-Category'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
cr.groupby('Sub-Category')['Profit','Sales'].agg(['sum']).plot.bar()
plt.title('Total Profit and Sales per Sub-Category')
# plt.legend('Profit')
# plt.legend('Sales')
plt.show()
# Out:
# C:\Users\s.DESKTOP-CSGKT6S.000\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
# Analyzing the product column
cr['Product Name'].nunique()
# Out:
# 1850

# %%
cr['Product Name'].value_counts()
# Out:
# Staple envelope                        48
# Easy-staple paper                      46
# Staples                                46
# Avery Non-Stick Binders                20
# Staples in misc. colors                19
#                                        ..
# Cisco 8961 IP Phone Charcoal            1
# Penpower WorldCard Pro Card Scanner     1
# Xerox 1922                              1
# Xerox 1989                              1
# Epson Perfection V600 Photo Scanner     1
# Name: Product Name, Length: 1850, dtype: int64

# %%
#Distribution of Top 10 Products
plt.figure(figsize=(12,10))
cr['Product Name'].value_counts().head(10).plot.pie(autopct="%1.1f%%")

# %%
#Count of Sub-Category region wise
plt.figure(figsize=(15,8))
sns.countplot(x="Sub-Category", hue="Region", data=cr)
plt.show()

# %%
cr['Customer ID'].nunique()
# Out:
# 793

# %%
cr_top10=cr['Customer Name'].value_counts().head(10)
cr_top10
# Out:
# William Brown          37
# Paul Prost             34
# John Lee               34
# Matt Abelman           34
# Chloris Kastensmidt    32
# Jonathan Doherty       32
# Edward Hooks           32
# Seth Vernon            32
# Emily Phan             31
# Zuschuss Carroll       31
# Name: Customer Name, dtype: int64

# %%
sns.barplot(x="Profit", y="Sub-Category", data=cr,palette='rainbow')

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x="Discount", y="Profit", data=cr,palette='rainbow')

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(data=cr, x="Sub-Category", y="Sales")

# %%
plt.figure(figsize=(20,12))
sns.countplot(x='State',data=cr,palette='rocket',order=cr['State'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %%
cr.hist(figsize=(10,10),bins=50)
plt.show()
